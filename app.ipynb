# %% [markdown]
# <a href="https://colab.research.google.com/github/tagagentic/app/blob/main/app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries if they are not already installed
# !pip install -q diffusers transformers torch pillow gspread google-auth google-auth-oauthlib google-auth-httplib2

# Import necessary libraries
from diffusers import StableDiffusionInpaintPipeline
import torch
from PIL import Image
from google.colab import auth
import os
import gspread
from google.auth import default
from google.colab import drive

# Authenticate and mount Google Drive
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Força a remontagem do Google Drive e limpa a pasta de cache
if os.path.exists('/content/drive'):
    drive.flush_and_unmount()
    print('Google Drive desmontado.')
drive.mount('/content/drive', force_remount=True)
print('Google Drive montado com sucesso!')

# Define input and output directories
INPUT_DIR = os.path.join('/content/drive/My Drive/input-logos')
OUTPUT_DIR = os.path.join('/content/drive/My Drive/output-logos')

# Create output directory if it doesn't exist
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Check if input directory exists
if not os.path.exists(INPUT_DIR):
    print(f"Erro: Diretório de entrada '{INPUT_DIR}' não encontrado.")
    os.makedirs(INPUT_DIR, exist_ok=True)
    print(f"Diretório de entrada '{INPUT_DIR}' criado. Adicione as imagens e execute novamente.")
else:
    # Initialize the inpainting pipeline
    device = "cuda" if torch.cuda.is_available() else "cpu"
    pipe = StableDiffusionInpaintPipeline.from_pretrained(
        "runwayml/stable-diffusion-inpainting",
        torch_dtype=torch.float16
    ).to(device)

    # Base prompt for logo generation
    BASE_PROMPT = (
        "The original image is a logo. Keep the style and composition intact, but make subtle creative variations."
    )

    # Function to process logos and generate 4 variations per logo
    def process_logos(input_dir, output_dir, base_prompt):
        for filename in os.listdir(input_dir):
            if filename.lower().endswith((".png", ".jpg", ".jpeg")):
                input_path = os.path.join(input_dir, filename)
                try:
                    print(f"Processando: {filename}")
                    init_image = Image.open(input_path).convert("RGB").resize((512, 512))  # Resize to a standard size
                    mask_image = Image.new("RGB", init_image.size, "white")  # Create a white mask

                    # Generate 4 variations of the logo
                    for i in range(4):
                        variation_prompt = f"{base_prompt} Variation {i + 1}: Add unique stylistic elements."
                        result = pipe(prompt=variation_prompt, image=init_image, mask_image=mask_image, num_inference_steps=50).images[0]
                        output_filename = f"{filename.split('.')[0]}_variation_{i + 1}.png"
                        output_path = os.path.join(output_dir, output_filename)
                        result.save(output_path)
                        print(f"Variação salva em: {output_path}")
                except Exception as e:
                    print(f"Erro ao processar {filename}: {e}")

    # Process the logos
    process_logos(INPUT_DIR, OUTPUT_DIR, BASE_PROMPT)
# Out:
# Google Drive desmontado.
# Mounted at /content/drive
# Google Drive montado com sucesso!
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_index.json:   0%|          | 0.00/548 [00:00<?, ?B/s]
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# safety_checker/config.json:   0%|          | 0.00/4.78k [00:00<?, ?B/s]
# (…)ature_extractor/preprocessor_config.json:   0%|          | 0.00/342 [00:00<?, ?B/s]
# text_encoder/config.json:   0%|          | 0.00/617 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# scheduler/scheduler_config.json:   0%|          | 0.00/313 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/748 [00:00<?, ?B/s]
# tokenizer/merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/492M [00:00<?, ?B/s]
# tokenizer/special_tokens_map.json:   0%|          | 0.00/472 [00:00<?, ?B/s]
# tokenizer/tokenizer_config.json:   0%|          | 0.00/806 [00:00<?, ?B/s]
# tokenizer/vocab.json:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/3.44G [00:00<?, ?B/s]
# vae/config.json:   0%|          | 0.00/552 [00:00<?, ?B/s]
# diffusion_pytorch_model.bin:   0%|          | 0.00/335M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/unet: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/unet.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# An error occurred while trying to fetch /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/vae: Error no file named diffusion_pytorch_model.safetensors found in directory /root/.cache/huggingface/hub/models--runwayml--stable-diffusion-inpainting/snapshots/8a4288a76071f7280aedbdb3253bdb9e9d5d84bb/vae.
# Defaulting to unsafe serialization. Pass `allow_pickle=False` to raise an error instead.
# Processando: crossmodalritual.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodalritual_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodalritual_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodalritual_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodalritual_variation_4.png
# Processando: agentescrossmodais.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/agentescrossmodais_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentescrossmodais_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentescrossmodais_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentescrossmodais_variation_4.png
# Processando: 3 pixels laranjas proximos do natural.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/3 pixels laranjas proximos do natural_variation_4.png
# Processando: agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/agentedebate - elabore uma logo na qual um cerebro tem a pontinha de baixo em formato triangular, lembrando o cerebro um balao de dialogo_variation_4.png
# Processando: mixritual.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/mixritual_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/mixritual_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/mixritual_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/mixritual_variation_4.png
# Processando: md4moe.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/md4moe_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/md4moe_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/md4moe_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/md4moe_variation_4.png
# Processando: kr4ser.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/kr4ser_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/kr4ser_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/kr4ser_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/kr4ser_variation_4.png
# Processando: hot4fd.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4fd_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4fd_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4fd_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4fd_variation_4.png
# Processando: hot4xp.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4xp_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4xp_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/hot4xp_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4xp_variation_4.png
# Processando: hot4dp.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4dp_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/hot4dp_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4dp_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/hot4dp_variation_4.png
# Processando: emcomitiva.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emcomitiva_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emcomitiva_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emcomitiva_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emcomitiva_variation_4.png
# Processando: gendeeper_branch.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/gendeeper_branch_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/gendeeper_branch_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/gendeeper_branch_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/gendeeper_branch_variation_4.png
# Processando: florescenciacanabica - flores de bem-me-quer-, maracuja e camomila.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/florescenciacanabica - flores de bem-me-quer-, maracuja e camomila_variation_4.png
# Processando: ensisanar.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/ensisanar_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/ensisanar_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/ensisanar_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/ensisanar_variation_4.png
# Processando: emodiversa - cortar coracao, 90graus base.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/emodiversa - cortar coracao, 90graus base_variation_4.png
# Processando: estaraverse.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/estaraverse_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/estaraverse_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/estaraverse_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/estaraverse_variation_4.png
# Processando: crossindex.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossindex_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossindex_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossindex_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossindex_variation_4.png
# Processando: crossmodais.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodais_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodais_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodais_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodais_variation_4.png
# Processando: crossmodaldebate.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodaldebate_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodaldebate_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodaldebate_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/crossmodaldebate_variation_4.png
# Processando: cryptoperfoma.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/cryptoperfoma_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/cryptoperfoma_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/cryptoperfoma_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/cryptoperfoma_variation_4.png
# Processando: casset.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/casset_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/casset_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/casset_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/casset_variation_4.png
# Processando: waytogoasis.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/waytogoasis_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/waytogoasis_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/waytogoasis_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/waytogoasis_variation_4.png
# Processando: zk4cfm.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/zk4cfm_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/zk4cfm_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/zk4cfm_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/zk4cfm_variation_4.png
# Processando: up4dca.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/up4dca_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/up4dca_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/up4dca_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/up4dca_variation_4.png
# Processando: tagdebate-laranja e lilas.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagdebate-laranja e lilas_variation_4.png
# Processando: sutiliza.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sutiliza_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sutiliza_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sutiliza_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sutiliza_variation_4.png
# Processando: tagagentic.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagagentic_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagagentic_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagagentic_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/tagagentic_variation_4.png
# Processando: metateca.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/metateca_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/metateca_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/metateca_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/metateca_variation_4.png
# Processando: moe4xp.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/moe4xp_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/moe4xp_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/moe4xp_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/moe4xp_variation_4.png
# Processando: modelos generativos - inverter onda.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/modelos generativos - inverter onda_variation_4.png
# Processando: nomelhorsentido.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/nomelhorsentido_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/nomelhorsentido_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/nomelhorsentido_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/nomelhorsentido_variation_4.png
# Processando: sanoexplorar.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sanoexplorar_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Potential NSFW content was detected in one or more images. A black image will be returned instead. Try again with a different prompt and/or seed.
# Variação salva em: /content/drive/My Drive/output-logos/sanoexplorar_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sanoexplorar_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/sanoexplorar_variation_4.png
# Processando: promptprotocol.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/promptprotocol_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/promptprotocol_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/promptprotocol_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/promptprotocol_variation_4.png
# Processando: saneagent.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/saneagent_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/saneagent_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/saneagent_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/saneagent_variation_4.png
# Processando: preferencil.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/preferencil_variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/preferencil_variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/preferencil_variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/preferencil_variation_4.png
# Processando: psicofisicacanabica .png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/psicofisicacanabica _variation_1.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/psicofisicacanabica _variation_2.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/psicofisicacanabica _variation_3.png
#   0%|          | 0/50 [00:00<?, ?it/s]
# Variação salva em: /content/drive/My Drive/output-logos/psicofisicacanabica _variation_4.png
